# %%
import turtle

# Tạo một đối tượng Turtle
t = turtle.Turtle()

# Thiết lập màu nền
turtle.Screen().bgcolor("pink")

# Vẽ mặt trời
t.penup()
t.goto(220, 200)
t.pendown()
t.color("yellow")
t.begin_fill()
t.circle(50)
t.end_fill()

# Vẽ tia sáng của mặt trời
t.penup()
t.goto(200, 250)
t.pendown()
t.color("yellow")
t.setheading(45)
for _ in range(8):
    t.forward(80)
    t.backward(80)
    t.right(45)
    t.penup()
    t.forward(35)
    t.right(90)
    t.forward(80)
    t.pendown()
    t.backward(80)

# Vẽ căn nhà
t.penup()
t.goto(-100, -100)
t.right(45)
t.pendown()
t.color("red")
t.begin_fill()
for _ in range(4):
    t.forward(200)
    t.left(90)
t.end_fill()

# Vẽ cửa sổ
t.penup()
t.goto(-60, -60)
t.pendown()
t.color("blue")
t.begin_fill()
t.goto(0, -60)
t.goto(0, 0)
t.goto(-60, 0)
t.goto(-60, -60)
t.end_fill()

#vẽ cửa
t.penup()
t.goto(30, -100)
t.pendown()
t.begin_fill()
t.goto(30, -20)
t.goto(90, -20)
t.goto(90, -100)
t.end_fill()

#vẽ mái nhà
t.penup()
t.goto (-100,100)
t.pendown()
t.color("grey")
t.begin_fill()
t.goto(0,150)
t.goto(100,100)
t.goto(-100,100)
t.end_fill()

# Vẽ cái cây
t.penup()
t.goto(-300, -100)
t.pendown()
t.color("brown")
t.begin_fill()
t.goto(-260, -100)
t.goto(-280, 0)
t.goto(-320, 0)
t.goto(-340, -100)
t.end_fill()

t.penup()
t.goto(-250, 0)
t.pendown()
t.color("green")
t.begin_fill()
t.goto(-300, 100)
t.goto(-350, 0)
t.goto(-250, 0)
t.end_fill()

done()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 102
#      99 t.goto(-250, 0)
#     100 t.end_fill()
# --> 102 done()
#
# NameError: name 'done' is not defined
